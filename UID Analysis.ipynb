# %%
from spark_uid import *

# %% [markdown]
# ### Choose crawl to load

# %%
crawl = 3
openwpm_log_dir = '/Users/sammacbeth/work/OpenWPM/logs/'
crawl_output_dir = './data/crawls/{}'.format(crawl)

# %% [markdown]
# ### Import crawl data or analyse from loads if it has not yet been analysed

# %%
import os
import json
from ast import literal_eval

if all(map(lambda path: os.path.exists(crawl_output_dir +'/'+ path), ['requests', 'uid_reach'])):
    requests = sc.textFile('{}/requests/'.format(crawl_output_dir)).map(json.loads)
    uid_reach = sc.textFile('{}/uid_reach/'.format(crawl_output_dir)).map(literal_eval).cache()
else:
    requests, uid_reach = run_analysis(sc, input_dir='{}/{}/'.format(openwpm_log_dir, crawl))
    save_analysis_rdds(requests, uid_reach, crawl_output_dir)

# %%
# get urls from crawl
import sqlite3
import pandas as pd
conn = sqlite3.connect('{}/crawl-data.sqlite'.format(openwpm_log_dir))
crawl_urls = pd.read_sql("SELECT site_url FROM site_visits WHERE crawl_id = {}".format(crawl), conn)
crawl_urls
# Out:
#                                   site_url
# 0                           http://ebay.de
# 1             http://ebay-kleinanzeigen.de
# 2                         http://google.de
# 3                       http://youtube.com
# 4                         http://amazon.de
# 5                           http://bild.de
# 6                       http://t-online.de
# 7                  http://suchen.mobile.de
# 8                            http://web.de
# 9                          http://jappy.de
# 10                          http://gmx.net
# 11                       http://zalando.de
# 12                       http://spiegel.de
# 13                 http://images.google.de
# 14                http://apps.facebook.com
# 15             http://immobilienscout24.de
# 16                     http://facebook.com
# 17                       http://wetter.com
# 18                      http://chefkoch.de
# 19                       http://my.ebay.de
# 20                        http://kicker.de
# 21                         http://focus.de
# 22                          http://msn.com
# 23                         http://arcor.de
# 24                         http://finya.de
# 25                       http://bonprix.de
# 26                          http://welt.de
# 27                          http://chip.de
# 28                        http://sport1.de
# 29                     http://willhaben.at
# ..                                     ...
# 867                       http://proxer.me
# 868                   http://epochtimes.de
# 869                     http://4players.de
# 870          http://motorsport-magazin.com
# 871                http://de.soccerway.com
# 872  http://darksouls3.wiki.fextralife.com
# 873                   http://kw.parship.de
# 874               http://flightradar24.com
# 875                  http://beate-uhse.com
# 876                          http://adf.ly
# 877                http://mein.t-mobile.de
# 878                    http://4teachers.de
# 879                http://payments.ebay.de
# 880                    http://juraforum.de
# 881                    http://farmerama.de
# 882                  http://search.chip.de
# 883                         http://yelp.de
# 884              http://en.diariodelweb.it
# 885               http://cumhuriyet.com.tr
# 886                  http://marktplaats.nl
# 887          http://gewinnspiel.tvmovie.de
# 888                  http://ottoversand.at
# 889                       http://dehner.de
# 890              http://manager-magazin.de
# 891                        http://kinox.tv
# 892                   http://autohaus24.de
# 893                       http://kimeta.de
# 894             http://aachener-zeitung.de
# 895                http://jalousiescout.de
# 896             http://frustfrei-lernen.de
#
# [897 rows x 1 columns]

# %% [markdown]
# ## Make UID Tables

# %%
uid_tables = uid_reach_as_dataframes(uid_reach, sqlContext)
register_tables(uid_tables)

# %%
query_top_uids(sqlContext).limit(20).toPandas()
# Out:
#     uid_id                 domain  duration  non_fp_uniques  tp_domains  uids  \
# 0        0        doubleclick.net  2.383779             847         238     2
# 1        1        doubleclick.net  2.251869             769         219     3
# 2        2        doubleclick.net  1.953368             638         185     2
# 3        3        doubleclick.net  1.944625             627         184     3
# 4        4             google.com  2.350390             670         138     1
# 5        7              adnxs.com  2.370054             295         112     1
# 6        9            adition.com  2.341146             285         109     1
# 7       10              adnxs.com  2.348995             290         109     1
# 8       15           facebook.com  2.206429             356         108     1
# 9       16           facebook.com  2.204574             356         108     2
# 10      13            adition.com  2.332022             284         108     1
# 11      25  googlesyndication.com  2.039740             344          95     1
# 12      29        doubleclick.net  2.382486             377          84     2
# 13      28            adition.com  2.293468             240          82     2
# 14      33             criteo.com  2.296528             211          82     1
# 15      34              google.de  2.291185             377          81     1
# 16      39              google.de  2.139000             355          77     2
# 17      40             adform.net  2.359973             201          76     1
# 18      45        doubleclick.net  2.321253             166          75     2
# 19      49             adform.net  2.360112             194          73     1
#
#     cookies  qs  ps
# 0         2   0   0
# 1         3   0   0
# 2         2   0   0
# 3         3   0   0
# 4         1   0   0
# 5         1   0   0
# 6         0   0   0
# 7         0   0   0
# 8         1   0   0
# 9         2   0   0
# 10        1   0   0
# 11        1   0   0
# 12        2   0   0
# 13        1   0   0
# 14        1   0   0
# 15        1   0   0
# 16        2   0   0
# 17        1   0   0
# 18        2   0   0
# 19        0   0   0

# %%
from IPython.display import display
check_id = 0
display(query_uid_id(uid_tables, check_id).toPandas())
query_uid_id(uid_tables, check_id, from_table='non_fp_uniques').limit(10).toPandas()
# Out:
#   classification           domain  key  source  uid_id  \
# 0            uid  doubleclick.net  IDE  cookie       0
# 1            uid  doubleclick.net   id  cookie       0
#
#                                                value
# 0  AHWqTUmtibDqZeS7vRUk7PMwSQcOMA9huBOxBNc1KwtCk1...
# 1  2280ee95690e0078||t=1484152725|et=730|cs=00221...
#         source  uid_id                                                url
# 0  referer_url       0    http://www.autobild.de/messen/auto-salon-paris/
# 1      referer       0  http://www.giga.de/apps/google-play-store/spec...
# 2          url       0                  http://www.tvtoday.de/tv-programm
# 3  referer_url       0  http://rtb-csync.smartadserver.com/redir/?part...
# 4          url       0                               http://www.ariva.de/
# 5      referer       0  https://aka-cdn.adtech.de/apps/397/Ad15458189S...
# 6          url       0     http://www.aboutyou.de/frauen/bekleidung/jeans
# 7          url       0  http://www.o2online.de/e-shop/apple/apple-ipho...
# 8      referer       0  http://tap2-cdn.rubiconproject.com/partner/scr...
# 9      referer       0                            https://www.zalando.de/

# %% [markdown]
# ## Make requests accessable to SparkSQL

# %%
request_tables = requests_as_dataframes(requests, sqlContext)
register_tables(request_tables)

# %%
sqlContext.sql("""\
SELECT * FROM request WHERE method = 'POST' LIMIT 10\
""").toPandas()
# Out:
#                      host method  \
# 0         www.youtube.com   POST
# 1         www.youtube.com   POST
# 2  content.googleapis.com   POST
# 3         www.youtube.com   POST
# 4         www.youtube.com   POST
# 5         www.youtube.com   POST
# 6         www.youtube.com   POST
# 7       fls-eu.amazon.com   POST
# 8           www.amazon.de   POST
# 9           www.amazon.de   POST
#
#                                                 path  port  res_status   rid  \
# 0                                       /ad_data_204   443         204   872
# 1                                       /ad_data_204   443         204   875
# 2  /youtubei/v1/log_interaction?alt=json&key=AIza...   443         200   895
# 3  /annotations_invideo?cap_hist=1&video_id=xc08E...   443         200   905
# 4  /get_endscreen?v=xc08ESKCg1k&client=1&ei=HWB2W...   443         200   907
# 5                                       /ad_data_204   443         204   945
# 6                                       /ad_data_204   443         204   984
# 7  /1/action-impressions/1/OP/csm/action/csm-feat...   443         200  1028
# 8  /ah/ajax/counter?ctr=desktop_ajax_atf&exp=1484...   443         202  1029
# 9                           /gp/overlay/display.html   443         200  1036
#
#   scheme                                               text             tld  \
# 0  https  dt=1484152843588&flash=24.0.0&frm=0&u_tz=60&u_...     youtube.com
# 1  https  dt=1484152844754&flash=24.0.0&frm=1&u_tz=60&u_...     youtube.com
# 2  https  {"context":{"client":{"hl":"en","gl":"DE","cli...  googleapis.com
# 3  https                                                        youtube.com
# 4  https  session_token=QUFFLUhqa3c3S0xWZTBLREtwSkQ1VHJx...     youtube.com
# 5  https  dt=1484152843588&flash=24.0.0&frm=0&u_tz=60&u_...     youtube.com
# 6  https  dt=1484152843588&flash=24.0.0&frm=0&u_tz=60&u_...     youtube.com
# 7  https                                                         amazon.com
# 8  https                                                          amazon.de
# 9  https  origSessionId=253-6706493-2004064&subPageType=...       amazon.de
#
#              ts                                                url
# 0  1.484153e+09                https://www.youtube.com/ad_data_204
# 1  1.484153e+09                https://www.youtube.com/ad_data_204
# 2  1.484153e+09  https://content.googleapis.com/youtubei/v1/log...
# 3  1.484153e+09  https://www.youtube.com/annotations_invideo?ca...
# 4  1.484153e+09  https://www.youtube.com/get_endscreen?v=xc08ES...
# 5  1.484153e+09                https://www.youtube.com/ad_data_204
# 6  1.484153e+09                https://www.youtube.com/ad_data_204
# 7  1.484153e+09  https://fls-eu.amazon.com/1/action-impressions...
# 8  1.484153e+09  https://www.amazon.de/ah/ajax/counter?ctr=desk...
# 9  1.484153e+09      https://www.amazon.de/gp/overlay/display.html
